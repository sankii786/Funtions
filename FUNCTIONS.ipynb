# %% [markdown]
# # ***Functions***

# %% [markdown]
# Q1 .  What is the difference between a function and a method in Python ?
#    -  Here, key differences between Method and Function in Python are explained. Java is also an OOP language, but there is no concept of Function in it. But Python has both concept of Method and Function.
#    - Python Method
#
#    - Method is called by its name, but it is associated to an object (dependent).
#    - 1 A method definition always includes 'self' as its first parameter.
#    - 2 A method is implicitly passed to the object on which it is invoked.
#    - 3 It may or may not return any data.
#    - 4 A method can operate on the data (instance variables) that is contained by the corresponding class
#    - Funtions Method
#    - 1 Function is block of code that is also called by its name. (independent)
#    - 2 The function can have different parameters or may not have any at all. - - 3 If any data (parameters) are passed, they are passed explicitly.
#    - It may or may not return any data.

# %% [markdown]
# Q2 -  Explain the concept of function arguments and parameters in Pytho ?
#    - Parameters are variables defined in a function declaration. This act as placeholders for the values (arguments) that will be passed to the function.
#    - Arguments are the actual values that you pass to the function when you call it. These values replace the parameters defined in the function.
#    - Parameters
#    - A parameter is the variable defined within the parentheses when we declare a function.
#    - Example .

# %%
# Here a,b are the parameters
def sum(a,b):
  print(a+b)

sum(1,2)
# Out:
# 3

# %% [markdown]
#   - Arguments
#    - An argument is a value that is passed to a function when it is called. It might be a variable, value or object passed to a function or method as input.
#
#    - Example:

# %%
def sum(a,b):
  print(a+b)

# Here the values 1,2 are arguments
sum(1,2)
# Out:
# 3

# %% [markdown]
# Q3 - What are the different ways to define and call a function in Python ?
#    - Python Functions is a block of statements that does a specific task. The idea is to put some commonly or repeatedly done task together and make a function so that instead of writing the same code again and again for different inputs, we can do the function calls to reuse code contained in it over and over again.
#    - Benefits of Using Functions
#    - Code Reuse
#    - Reduced code length
#    - Increased redability of code
#    - Types of Functions in Python :-
#    - Built-in library function: These are Standard functions in Python that are available to use.
#    - User-defined function: We can create our own functions based on our requirements.

# %% [markdown]
# Q4 - What is the purpose of the `return` statement in a Python function ?
#    - The return statement in a Python function serves two primary purposes:
#    - Exiting the Function:
#    - When a return statement is encountered within a function, the function's execution immediately terminates at that point. Any code following the return statement within the function will not be executed.
#    - Sending a Value Back to the Caller:
#    - The return statement allows a function to send a value or set of values back to the part of the code that called it. This returned value can then be used for further processing, assigned to a variable, passed as an argument to another function, or otherwise utilized within the program.

# %% [markdown]
# Q5 - What are iterators in Python and how do they differ from iterables ?
#    - In Python, iterables and iterators are distinct but related concepts fundamental to how looping and data traversal work.
#    - Iterables:
#    - An iterable is any Python object that can be looped over, meaning it can return its members one at a time. This includes built-in sequence types like lists, tuples, strings, and dictionaries, as well as user-defined objects that implement the __iter__ method. When you use a for loop, you are iterating over an iterable.
#    - An iterator is an object that represents a stream of data and produces values one at a time. It implements the iterator protocol, which requires two methods:
#    - __iter__(): This method returns the iterator object itself.
#    - __next__(): This method returns the next item from the iterator. If there are no more items, it raises a StopIteration exception.

# %% [markdown]
# Q6 -  Explain the concept of generators in Python and how they are defined ?
#    - Generators in Python are a special type of iterable that produce values one at a time, on demand, rather than storing all values in memory simultaneously. This "lazy evaluation" makes them highly memory-efficient, especially when dealing with large datasets or potentially infinite sequences.
#    - How Generators are Defined:
#    - Generators are defined in Python using functions, but instead of using the return keyword to return a value and terminate the function, they use the yield keyword.
#    - Generator Function: A function containing one or more yield statements becomes a generator function. When called, it doesn't execute the function body immediately but instead returns a generator object.

# %% [markdown]
# Q7 - What are the advantages of using generators over regular functions?
#    - Generators offer several advantages over regular functions, particularly when dealing with sequences of data or iterative processes:
#    - Memory Efficiency:
#    - Generators produce values one at a time, on demand, using the yield keyword. This contrasts with regular functions that might return a complete list or collection, which can consume significant memory, especially for large datasets or infinite sequences.
#    - Lazy Evaluation:
#    - Values are generated only when requested, rather than all at once. This "lazy" approach saves processing time and CPU cycles as computations are performed only when necessary.
#    - Handling Large or Infinite Sequences:
#    - Due to their memory efficiency and lazy evaluation, generators are well-suited for processing very large datasets that might not fit entirely in memory, or for representing infinite sequences (like the Fibonacci sequence) without needing to pre-calculate and store all elements.

# %% [markdown]
# Q8 - What is a lambda function in Python and when is it typically used ?
#    - A lambda function in Python is a small, anonymous function defined using the lambda keyword. Unlike regular functions defined with def, lambda functions do not have a name and are limited to a single expression. This expression is evaluated, and its result is returned when the lambda function is invoked.
#    - When are lambda functions typically used?
#    - Lambda functions are typically used in situations where a small, single-expression function is required for a short period and a full def function definition would be unnecessarily verbose or cumbersome. Common use cases include:
#
#
# *   List item
# *   List item
#
# -  As arguments to higher-order functions: Lambda functions are frequently used with built-in functions like map(), filter(), sorted(), and reduce(), which accept functions as arguments.

# %% [markdown]
# Q9 - . Explain the purpose and usage of the `map()` function in Python ?
#    - The map() function in Python is a built-in higher-order function that applies a given function to each item of an iterable (like a list, tuple, set, etc.) and returns a map object (an iterator) containing the results. It provides a concise and efficient way to perform transformations on data within an iterable without explicitly writing a for loop.
#   -  Purpose:
#   - The primary purpose of map() is to:
#   -  Transform data:
#   -Apply a specific operation or transformation to every element in an iterable.
#   -Simplify code:
#   - Reduce the need for explicit for loops when performing element-wise operations, leading to more compact and often more readable code.
#   -Improve performance (in some cases):
#   - For large iterables, map() can be more memory-efficient than creating a new list using a for loop and appending elements, as it returns an iterator that generates values on demand.

# %% [markdown]
# Q10 - What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
#    - The map(), filter(), and reduce() functions in Python are built-in higher-order functions used for processing iterables in a functional programming style. They differ in their purpose and how they transform or aggregate data:
#    - Map(function, iterable):
#    - Purpose: Applies a given function to each item in an iterable and returns an iterator that yields the results.
#    - Output: An iterator (which can be converted to a list, tuple, etc.) containing the transformed elements. The length of the output is always the same as the input iterable.
#
#   - Filter(function, iterable):
#   - Purpose: Constructs an iterator from elements of an iterable for which a function returns True. The function must return a boolean value.
#   - Output: An iterator (which can be converted to a list, tuple, etc.) containing only the elements that satisfy the given condition. The length of the output can be less than or equal to the input iterable.
#
#   - Reduce(function, iterable, initializer):
#   - Purpose: Applies a function cumulatively to the items of an iterable, from left to right, so as to reduce the iterable to a single value. It is part of the functools module and needs to be imported.
#   - Output: A single, accumulated value.

# %% [markdown]
# Q11 - Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given
# list:[47,11,42,13];
#
# ![252525.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # ***Practical Questions:***

# %% [markdown]
# Q1 -  - Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in
# the list.

# %%
def sum_even_numbers(numbers_list):

  even_sum = 0
  for number in numbers_list:
    if number % 2 == 0:
      even_sum += number
  return even_sum

# %% [markdown]
# Q2 -  Create a Python function that accepts a string and returns the reverse of that string.

# %%
def reverse_string(input_string):
  """
  Reverses a given string.

  Args:
    input_string: The string to be reversed.

  Returns:
    The reversed string.
  """
  return input_string[::-1]

# %% [markdown]
# Q3 - Implement a Python function that takes a list of integers and returns a new list containing the squares of
# each number.

# %%
def square_numbers_in_list(numbers):
  """
  Takes a list of integers and returns a new list containing the squares of each number.

  Args:
    numbers: A list of integers.

  Returns:
    A new list containing the squares of the input numbers.
  """
  squared_numbers = [num ** 2 for num in numbers]
  return squared_numbers

# Example usage:
my_list = [1, 2, 3, 4, 5]
result_list = square_numbers_in_list(my_list)
print(result_list)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# Q4 - Write a Python function that checks if a given number is prime or not from 1 to 200.

# %%
import math

def is_prime(number):
    """
    Checks if a given number is prime.

    Args:
        number: An integer.

    Returns:
        True if the number is prime, False otherwise.
    """
    if number <= 1:
        return False  # Numbers less than or equal to 1 are not prime

    # Check for divisibility from 2 up to the square root of the number
    for i in range(2, int(math.sqrt(number)) + 1):
        if number % i == 0:
            return False  # If divisible, it's not prime

    return True  # If no divisors found, it's prime

def check_primes_up_to_200():
    """
    Checks and prints whether each number from 1 to 200 is prime.
    """
    for num in range(1, 201):  # Iterate from 1 to 200 (inclusive)
        if is_prime(num):
            print(f"{num} is a prime number.")
        else:
            print(f"{num} is not a prime number.")

# Example usage:
# check_primes_up_to_200()

# %% [markdown]
# Q5 - Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of
# terms.

# %%
class FibonacciIterator:
    def __init__(self, num_terms):
        """
        Initializes the FibonacciIterator.

        Args:
            num_terms (int): The number of Fibonacci terms to generate.
        """
        if num_terms < 0:
            raise ValueError("Number of terms must be a non-negative integer.")
        self._num_terms = num_terms
        self._current_term = 0  # Tracks the index of the current term
        self._a = 0  # First term of the Fibonacci sequence
        self._b = 1  # Second term of the Fibonacci sequence

    def __iter__(self):
        """
        Returns the iterator object itself.
        """
        return self

    def __next__(self):
        """
        Generates the next Fibonacci number.

        Raises:
            StopIteration: When all specified terms have been generated.
        """
        if self._current_term < self._num_terms:
            if self._current_term == 0:
                result = self._a
            elif self._current_term == 1:
                result = self._b
            else:
                result = self._a + self._b
                self._a, self._b = self._b, result  # Update for the next iteration
            self._current_term += 1
            return result
        else:
            raise StopIteration

# %% [markdown]
# Q6 - Write a generator function in Python that yields the powers of 2 up to a given exponent.

# %%
def powers_of_2_generator(max_exponent):
    """
    Yields powers of 2 up to a given maximum exponent.

    Args:
        max_exponent (int): The highest exponent for which to calculate 2's power.
                            The generator will yield 2^0, 2^1, ..., 2^max_exponent.
    """
    current_exponent = 0
    while current_exponent <= max_exponent:
        yield 2 ** current_exponent
        current_exponent += 1

# %% [markdown]
# Q7 - Implement a generator function that reads a file line by line and yields each line as a string.

# %%
def read_file_line_by_line(file_path):
    """
    Reads a file line by line using a generator and yields each line as a string.

    Args:
        file_path (str): The path to the file to be read.

    Yields:
        str: Each line of the file as a string, with leading/trailing whitespace removed.
    """
    try:
        with open(file_path, 'r') as file:
            for line in file:
                yield line.strip()
    except FileNotFoundError:
        print(f"Error: The file '{file_path}' was not found.")
    except Exception as e:
        print(f"An error occurred while reading the file: {e}")

# Example Usage:
if __name__ == "__main__":
    # Create a dummy file for demonstration
    with open("sample.txt", "w") as f:
        f.write("This is line 1.\n")
        f.write("  This is line 2 with extra spaces.  \n")
        f.write("Line 3.\n")

    print("Reading 'sample.txt' line by line:")
    for line in read_file_line_by_line("sample.txt"):
        print(line)

    print("\nAttempting to read a non-existent file:")
    for line in read_file_line_by_line("non_existent_file.txt"):
        print(line)
# Out:
# Reading 'sample.txt' line by line:
# This is line 1.
# This is line 2 with extra spaces.
# Line 3.
#
# Attempting to read a non-existent file:
# Error: The file 'non_existent_file.txt' was not found.

# %% [markdown]
# Q8 - Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.

# %%
# shorted
data = [('apple', 3), ('banana', 1), ('cherry', 2), ('date', 4)]
sorted_data = sorted(data, key=lambda item: item[1])
print(sorted_data)
# Out:
# [('banana', 1), ('cherry', 2), ('apple', 3), ('date', 4)]

# %%
# short
data = [('apple', 3), ('banana', 1), ('cherry', 2), ('date', 4)]
data.sort(key=lambda item: item[1])
print(data)
# Out:
# [('banana', 1), ('cherry', 2), ('apple', 3), ('date', 4)]

# %% [markdown]
# Q9 - Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.

# %%
def celsius_to_fahrenheit(celsius):
  """Converts a temperature from Celsius to Fahrenheit."""
  return (celsius * 9/5) + 32

# List of temperatures in Celsius
celsius_temperatures = [0, 10, 25, 37.5, 100]

# Use map() to apply the conversion function to each element in the list
fahrenheit_temperatures = map(celsius_to_fahrenheit, celsius_temperatures)

# Convert the map object to a list for display
fahrenheit_list = list(fahrenheit_temperatures)

print(f"Celsius Temperatures: {celsius_temperatures}")
print(f"Fahrenheit Temperatures: {fahrenheit_list}")
# Out:
# Celsius Temperatures: [0, 10, 25, 37.5, 100]
# Fahrenheit Temperatures: [32.0, 50.0, 77.0, 99.5, 212.0]

# %% [markdown]
# Q10 - Create a Python program that uses `filter()` to remove all the vowels from a given string

# %%
def remove_vowels(input_string):
  """Removes all vowels (case-insensitive) from a given string using filter().

  Args:
    input_string: The string to remove vowels from.

  Returns:
    A new string with all vowels removed.
  """
  vowels = "aeiouAEIOU"  #
  # Use filter() with a lambda function to keep characters that are not vowels
  filtered_chars = filter(lambda char: char not in vowels, input_string) #
  # Join the filtered characters back into a string
  return "".join(filtered_chars)

# Example usage
input_str = "Hello World!"
output_str = remove_vowels(input_str)
print(f"Original string: {input_str}")
print(f"String without vowels: {output_str}")

input_str_2 = "Python Programming"
output_str_2 = remove_vowels(input_str_2)
print(f"Original string: {input_str_2}")
print(f"String without vowels: {output_str_2}")
# Out:
# Original string: Hello World!
# String without vowels: Hll Wrld!
# Original string: Python Programming
# String without vowels: Pythn Prgrmmng
